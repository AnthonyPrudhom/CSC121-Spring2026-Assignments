# %% [markdown]
# <a href="https://colab.research.google.com/github/AnthonyPrudhom/CSC121-Spring2026-Assignments/blob/main/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# (None)

# PROGRAM LOGIC
#1. define variable
#2. calculate age by subtracting current from birth year.
#3. print top boarderline with string multiplication.
#3.print bio sentence template combined with bio variables, age is converted to string data type.
#4. print bottom boarderline with string multiplication.


name = "Anthony"

goal = "learn programming and create scripts"

age = current_year - birth_year

birth_year = 2004

current_year = 2026

print("="*25)
print("My Name is " + name + " and i am " + str(age) + " years old. My goal is to " + goal)
print("="*25)
# Out:
# ...
# My Name is Anthony and i am 22 years old. My goal is to learn programming and create scripts
# ...
