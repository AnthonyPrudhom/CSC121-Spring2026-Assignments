# %% [markdown]
# <a href="https://colab.research.google.com/github/AnthonyPrudhom/CSC121-Spring2026-Assignments/blob/main/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def print_bio(name, age, goal):
  print("="*25)
  print("Name: "+ name+", " + str(age)+ " Goal: " + goal)
  print("="*25)
  print("\n")


print_bio("Anthony", 21, "make money")

print_bio("Keanu Reeves", 60, "ride a motorycle")

print_bio("shmoopy", 60, "be themselves and have fun")
# Out:
# ...
# Name: Anthony, 21 Goal: make money
# ...
#
#
# ...
# Name: Keanu Reeves, 60 Goal: ride a motorycle
# ...
#
#
# ...
# Name: shmoopy, 60 Goal: be themselves and have fun
# ...

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define print_bio with three parameters: name, age, and goal.
def print_bio(name, age, goal):
  # 2. Inside the function, use string multiplication (*) for a border line.
  print("="*25)
  # 3. Print the bio details using the parameter names.
  print("Name: "+ name+", " + str(age)+ " Goal: " + goal)
   # 4. Inside the function, use string multiplication (*) for 2nd border line.
  print("="*25)


# PROGRAM LOGIC
# 1. Call print_bio using my own info.
print_bio("Anthony", 21, "make money")
# 2. Call print_bio using [Name of Famous Person].
# 3. Call print_bio using [Name of Fictional Character].
