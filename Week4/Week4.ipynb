# %% [markdown]
# <a href="https://colab.research.google.com/github/AnthonyPrudhom/CSC121-Spring2026-Assignments/blob/main/Week4/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define print_bio with three parameters: name, age, and goal.
def print_bio(name, age, goal):
  # 2. Inside the function, use string multiplication (*) for a border line.
  print("="*25)
  # 3. Print the bio details using the parameter names.
  print("Name: "+ name+", " + "Age: " + str(age)+ ", Goal: " + goal)
  # 4. Inside the function, use string multiplication (*) for 2nd border line.
  print("="*25)
  # 5. print blank line space
  print("\n")

# PROGRAM LOGIC
# 1. Call print_bio using my own info.
print_bio("Anthony", 21, "make money")
# 2. Call print_bio using [Name of Famous Person].
print_bio("Keanu Reeves", 60, "ride a motorcycle")
# 3. Call print_bio using [Name of Fictional Character].
print_bio("Shmoopy", 60, "be themselves and have fun")
# Out:
# =========================
# Name: Anthony, Age: 21, Goal: make money
# =========================
#
#
# =========================
# Name: Keanu Reeves, Age: 60, Goal: ride a motorcycle
# =========================
#
#
# =========================
# Name: Shmoopy, Age: 60, Goal: be themselves and have fun
# =========================
