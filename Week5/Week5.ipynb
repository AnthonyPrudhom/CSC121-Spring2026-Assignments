# %% [markdown]
# <a href="https://colab.research.google.com/github/AnthonyPrudhom/CSC121-Spring2026-Assignments/blob/main/Week5/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define calculate_ticket(age, hour)
def calculate_ticket(age, hour):
# 2. Logic: If age <= 12 or age >= 65, price = 8. Otherwise, price = 12.
  if (age<=12)|(age>=65):
      price = 8.00
  else:
      price = 12.00
# 3. Logic: If hour < 17, subtract 2 from the price.
# 4. Print the final price.
  print(price)

# PROGRAM LOGIC
# 1. input() for age (int)
age1 = int(input())
# 2. input() for movie hour (int)
hour1 = int(input())
# 3. Call calculate_ticket()
calculate_ticket(age1, hour1)
# Out:
# 13
# 13
# 12.0
